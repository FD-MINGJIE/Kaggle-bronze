# %% [markdown]
# ## Load Everything

# %%
# %matplotlib inline
# 导入一些库
import pandas as pd
import numpy as np
import math
import gc
import copy
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns
from lightgbm import LGBMRegressor

# %%
DATA_PATH = '../input'
SUBMISSIONS_PATH = './'
# 使用原子的序号来对表示这些原子
ATOMIC_NUMBERS = {
    'H': 1,
    'C': 6,
    'N': 7,
    'O': 8,
    'F': 9
}

# %%
# 导入库
import os
os.listdir(DATA_PATH)
# Out:
# ['champs-scalar-coupling', 'quantum-machine-9-qm9']

# %% [markdown]
# ## Load Dataset

# %%
# 训练集的数据类型设置
train_dtypes = {
    'molecule_name': 'category',
    'atom_index_0': 'int8',
    'atom_index_1': 'int8',
    'type': 'category',
    'scalar_coupling_constant': 'float32'
}
# 读取训练集文件
train_csv = pd.read_csv(f'{DATA_PATH}/champs-scalar-coupling/train.csv', index_col='id', dtype=train_dtypes)
# 将molecule_name的格式从dsgdb9nsd_xx改成xx方面处理
train_csv['molecule_index'] = train_csv.molecule_name.str.replace('dsgdb9nsd_', '').astype('int32')
train_csv = train_csv[['molecule_index', 'atom_index_0', 'atom_index_1', 'type', 'scalar_coupling_constant']]
#打印前10个元素
train_csv.head(10)
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#     molecule_index  atom_index_0  atom_index_1  type  scalar_coupling_constant
# id
# 0   1               1             0             1JHC  84.807602
# 1   1               1             2             2JHH -11.257000
# 2   1               1             3             2JHH -11.254800
# 3   1               1             4             2JHH -11.254300
# 4   1               2             0             1JHC  84.807404
# 5   1               2             3             2JHH -11.254100
# 6   1               2             4             2JHH -11.254800
# 7   1               3             0             1JHC  84.809303
# 8   1               3             4             2JHH -11.254300
# 9   1               4             0             1JHC  84.809502

# %%
# 读取需要提交的文件
submission_csv = pd.read_csv(f'{DATA_PATH}/champs-scalar-coupling/sample_submission.csv', index_col='id')

# %%
# 读取测试文件
test_csv = pd.read_csv(f'{DATA_PATH}/champs-scalar-coupling/test.csv', index_col='id', dtype=train_dtypes)
test_csv['molecule_index'] = test_csv['molecule_name'].str.replace('dsgdb9nsd_', '').astype('int32')
test_csv = test_csv[['molecule_index', 'atom_index_0', 'atom_index_1', 'type']]
test_csv.head(10)
# Out:
#          molecule_index  atom_index_0  atom_index_1  type
# id
# 4658147  4               2             0             2JHC
# 4658148  4               2             1             1JHC
# 4658149  4               2             3             3JHH
# 4658150  4               3             0             1JHC
# 4658151  4               3             1             2JHC
# 4658152  15              3             0             1JHC
# 4658153  15              3             2             3JHC
# 4658154  15              3             4             2JHH
# 4658155  15              3             5             2JHH
# 4658156  15              4             0             1JHC

# %%
# 结构数据类型
structures_dtypes = {
    'molecule_name': 'category',
    'atom_index': 'int8',
    'atom': 'category',
    'x': 'float32',
    'y': 'float32',
    'z': 'float32'
}
structures_csv = pd.read_csv(f'{DATA_PATH}/champs-scalar-coupling/structures.csv', dtype=structures_dtypes)
structures_csv['molecule_index'] = structures_csv.molecule_name.str.replace('dsgdb9nsd_', '').astype('int32')
structures_csv = structures_csv[['molecule_index', 'atom_index', 'atom', 'x', 'y', 'z']]
structures_csv['atom'] = structures_csv['atom'].replace(ATOMIC_NUMBERS).astype('int8')
structures_csv.head(10)
# Out:
#    molecule_index  atom_index  atom         x         y         z
# 0  1               0           6    -0.012698  1.085804  0.008001
# 1  1               1           1     0.002150 -0.006031  0.001976
# 2  1               2           1     1.011731  1.463751  0.000277
# 3  1               3           1    -0.540815  1.447527 -0.876644
# 4  1               4           1    -0.523814  1.437933  0.906397
# 5  2               0           7    -0.040426  1.024108  0.062564
# 6  2               1           1     0.017257  0.012545 -0.027377
# 7  2               2           1     0.915789  1.358745 -0.028758
# 8  2               3           1    -0.520278  1.343532 -0.775543
# 9  3               0           8    -0.034360  0.977540  0.007602

# %%
# 降低内存使用，感觉每个变量的取值范围将其动态改变类型
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
# 将Categorical类型的数据变成热编码数据
def dummies(df, list_cols):
    for col in list_cols:
        df_dummies = pd.get_dummies(df[col], drop_first=True, 
                                    prefix=(str(col)))
        df = pd.concat([df, df_dummies], axis=1)
    return df

# 添加QM9特征
def add_qm9_features(df):
    # 读取qm9数据
    data_qm9 = pd.read_pickle('../input/quantum-machine-9-qm9/data.covs.pickle')
    # 抛去一些无用的和重复的特征
    to_drop = ['type', 
               'linear', 
               'atom_index_0', 
               'atom_index_1', 
               'scalar_coupling_constant', 
               'U', 'G', 'H', 
               'mulliken_mean', 'r2', 'U0']
    data_qm9 = data_qm9.drop(columns = to_drop, axis=1)
    # 减少内存
    data_qm9 = reduce_mem_usage(data_qm9,verbose=False)
    # 将molecule_index改成
    data_qm9['molecule_index'] = data_qm9.molecule_name.str.replace('dsgdb9nsd_', '').astype('int32')
    data_qm9=data_qm9.drop(columns=['molecule_name'])
    # 将qm9特征加入到df里面去
    df = pd.merge(df, data_qm9, how='left', on=['molecule_index','id'])
    # 抛去molecule_index,id这个对我们预测没啥帮助，此时df已经是最后的训练集或者测试集，特征工程已经处理结束
    df=df.drop(columns=['molecule_index','id'])
    del data_qm9
    gc.collect()
    return df

# %% [markdown]
# ## Build Distance Dataset

# %%
# 根据耦合键的类型，提取特定的数据
def build_type_dataframes(base, structures, coupling_type):
    base = base[base['type'] == coupling_type].drop('type', axis=1).copy()
    base = base.reset_index()
    base['id'] = base['id'].astype('int32')
    structures = structures[structures['molecule_index'].isin(base['molecule_index'])]
    return base, structures

# %%
# 从structure根据molecule_index和atom_index来得到得到atom的坐标
def add_coordinates(base, structures, index):
    df = pd.merge(base, structures, how='inner',
                  left_on=['molecule_index', f'atom_index_{index}'],
                  right_on=['molecule_index', 'atom_index']).drop(['atom_index'], axis=1)
    df = df.rename(columns={
        'atom': f'atom_{index}',
        'x': f'x_{index}',
        'y': f'y_{index}',
        'z': f'z_{index}'
    })
    return df

# %%
# 添加原子的信息
def add_atoms(base, atoms):
    df = pd.merge(base, atoms, how='inner',
                  on=['molecule_index', 'atom_index_0', 'atom_index_1'])
    return df

# %%
# 除了原有的atom_index_0和atom_index_1的那些行不加进去，其它的都加进去
def merge_all_atoms(base, structures):
    df = pd.merge(base, structures, how='left',
                  left_on=['molecule_index'],
                  right_on=['molecule_index'])
    df = df[(df.atom_index_0 != df.atom_index) & (df.atom_index_1 != df.atom_index)]
    return df

# %%
# 得到中心点的坐标
def add_center(df):
    df['x_c'] = ((df['x_1'] + df['x_0']) * np.float32(0.5))
    df['y_c'] = ((df['y_1'] + df['y_0']) * np.float32(0.5))
    df['z_c'] = ((df['z_1'] + df['z_0']) * np.float32(0.5))

# 得到到中心点的距离
def add_distance_to_center(df):
    df['d_c'] = ((
        (df['x_c'] - df['x'])**np.float32(2) +
        (df['y_c'] - df['y'])**np.float32(2) + 
        (df['z_c'] - df['z'])**np.float32(2)
    )**np.float32(0.5))

# 计算下标suffix1,和suffix2之间距离
def add_distance_between(df, suffix1, suffix2):
    df[f'd_{suffix1}_{suffix2}'] = ((
        (df[f'x_{suffix1}'] - df[f'x_{suffix2}'])**np.float32(2) +
        (df[f'y_{suffix1}'] - df[f'y_{suffix2}'])**np.float32(2) + 
        (df[f'z_{suffix1}'] - df[f'z_{suffix2}'])**np.float32(2)
    )**np.float32(0.5))

# %%
# 计算各个原子间的距离
def add_distances(df):
    n_atoms = 1 + max([int(c.split('_')[1]) for c in df.columns if c.startswith('x_')])
    for i in range(1, n_atoms):
        for vi in range(min(4, i)):
            add_distance_between(df, i, vi)

# %%
# 增加一个特征，该特征为molecule_index的分子对应原子的个数
def add_n_atoms(base, structures):
    dfs = structures['molecule_index'].value_counts().rename('n_atoms').to_frame()
    return pd.merge(base, dfs, left_on='molecule_index', right_index=True)

# %%
# 根据耦合类型来提取特定的数据，进行小测试
coupling_type='1JHC'
base, structures = build_type_dataframes(train_csv, structures_csv, coupling_type)

# %%
# base的头部
base.head()
# Out:
#    id  molecule_index  atom_index_0  atom_index_1  scalar_coupling_constant
# 0  0   1               1             0             84.807602
# 1  4   1               2             0             84.807404
# 2  7   1               3             0             84.809303
# 3  9   1               4             0             84.809502
# 4  17  5               2             0             171.220001

# %%
# stuctures的头部
structures.head()
# Out:
#    molecule_index  atom_index  atom         x         y         z
# 0  1               0           6    -0.012698  1.085804  0.008001
# 1  1               1           1     0.002150 -0.006031  0.001976
# 2  1               2           1     1.011731  1.463751  0.000277
# 3  1               3           1    -0.540815  1.447527 -0.876644
# 4  1               4           1    -0.523814  1.437933  0.906397

# %%
# 添加第一个原子的坐标
base = add_coordinates(base, structures, 0)
base.head()
# Out:
#    id  molecule_index  atom_index_0  atom_index_1  scalar_coupling_constant  \
# 0  0   1               1             0             84.807602
# 1  4   1               2             0             84.807404
# 2  7   1               3             0             84.809303
# 3  9   1               4             0             84.809502
# 4  17  5               2             0             171.220001
#
#    atom_0       x_0       y_0       z_0
# 0  1       0.002150 -0.006031  0.001976
# 1  1       1.011731  1.463751  0.000277
# 2  1      -0.540815  1.447527 -0.876644
# 3  1      -0.523814  1.437933  0.906397
# 4  1      -0.027803  2.198949  0.014154

# %%
# 添加第二个原子的坐标
base = add_coordinates(base, structures, 1)
base.head()
# Out:
#    id  molecule_index  atom_index_0  atom_index_1  scalar_coupling_constant  \
# 0  0   1               1             0             84.807602
# 1  4   1               2             0             84.807404
# 2  7   1               3             0             84.809303
# 3  9   1               4             0             84.809502
# 4  17  5               2             0             171.220001
#
#    atom_0       x_0       y_0       z_0  atom_1       x_1       y_1       z_1
# 0  1       0.002150 -0.006031  0.001976  6      -0.012698  1.085804  0.008001
# 1  1       1.011731  1.463751  0.000277  6      -0.012698  1.085804  0.008001
# 2  1      -0.540815  1.447527 -0.876644  6      -0.012698  1.085804  0.008001
# 3  1      -0.523814  1.437933  0.906397  6      -0.012698  1.085804  0.008001
# 4  1      -0.027803  2.198949  0.014154  6      -0.013324  1.132466  0.008276

# %%
# 构建需要跑的数据集
def build_couple_dataframe(some_csv, structures_csv, coupling_type, n_atoms=10):
    # 得到base，structures
    base, structures = build_type_dataframes(some_csv, structures_csv, coupling_type)
    # 添加原子1，原子2的坐标
    base = add_coordinates(base, structures, 0)
    base = add_coordinates(base, structures, 1)
    # 扔掉原子1，2的序号的两列
    base = base.drop(['atom_0', 'atom_1'], axis=1)
    #  扔掉id这一列
    atoms = base.drop('id', axis=1).copy()
    
    # 如果有scalar_coupling_constant这一列，则丢掉，scalar_coupling_constant这列是y的值
    if 'scalar_coupling_constant' in some_csv:
        atoms = atoms.drop(['scalar_coupling_constant'], axis=1)
        
    # 添加中心点
    add_center(atoms)
    
    # 删掉原子1，原子2的坐标，现在用中心点来替代
    atoms = atoms.drop(['x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1'], axis=1)

    # 合并所有的原子
    atoms = merge_all_atoms(atoms, structures)
    
    # 对所有的原子添加到中心的距离
    add_distance_to_center(atoms)
    
    # 删除中心点位置
    atoms = atoms.drop(['x_c', 'y_c', 'z_c', 'atom_index'], axis=1)
    
    # 按照molecule_index,atom_index_0,atom_index_1,d_c来对atoms进行排序
    atoms.sort_values(['molecule_index', 'atom_index_0', 'atom_index_1', 'd_c'], inplace=True)
    
    # 提取原子小于n_atoms的分子
    atom_groups = atoms.groupby(['molecule_index', 'atom_index_0', 'atom_index_1'])
    atoms['num'] = atom_groups.cumcount() + 2
    atoms = atoms.drop(['d_c'], axis=1)
    atoms = atoms[atoms['num'] < n_atoms]

    # 对索引设置并通过molecule_index展开
    atoms = atoms.set_index(['molecule_index', 'atom_index_0', 'atom_index_1', 'num']).unstack()
    atoms.columns = [f'{col[0]}_{col[1]}' for col in atoms.columns]
    atoms = atoms.reset_index()
    
    # 转回int8的类型
    for col in atoms.columns:
        if col.startswith('atom_'):
            atoms[col] = atoms[col].fillna(0).astype('int8')
            
    # 转类型
    atoms['molecule_index'] = atoms['molecule_index'].astype('int32')
    
    # 添加原子信息
    full = add_atoms(base, atoms)
    
    # 添加距离
    add_distances(full)
    
    # 根据id来进行重新排序
    full.sort_values('id', inplace=True)
    
    return full

# %%
# 生成需要使用的label
def take_n_atoms(df, n_atoms, four_start=4):
    labels = []
    for i in range(2, n_atoms):
        label = f'atom_{i}'
        labels.append(label)

    for i in range(n_atoms):
        num = min(i, 4) if i < four_start else 4
        for j in range(num):
            labels.append(f'd_{i}_{j}')
    if 'scalar_coupling_constant' in df:
        labels.append('scalar_coupling_constant')
    labels=['id','molecule_index']+labels
    return df[labels]

# %% [markdown]
# ## Check XGBOOST with the smallest type

# %% [markdown]
# We don't calculate distances for `d_0_x`, `d_1_1`, `d_2_2`, `d_2_3`, `d_3_3` because we already have them in later atoms(`d_0_1` == `d_1_0`) or they are equal to zeros(e.g. `d_1_1`, `d_2_2`).

# %% [markdown]
# ## Submission Model

# %%
# 生成x,y数据
def build_x_y_data(some_csv, coupling_type, n_atoms):
    full = build_couple_dataframe(some_csv, structures_csv, coupling_type, n_atoms=n_atoms)
    df = take_n_atoms(full, n_atoms)
    df = df.fillna(0)
    df=add_qm9_features(df)
    print(df.columns)
    
    if 'scalar_coupling_constant' in df:
        X_data = df.drop(['scalar_coupling_constant'], axis=1).values.astype('float32')
        y_data = df['scalar_coupling_constant'].values.astype('float32')
    else:
        X_data = df.values.astype('float32')
        y_data = None
    
    return X_data, y_data

# %%
# 拿出1JHN进行一个测试
tx,ty=build_x_y_data(train_csv, '1JHN', 7)
# Out:
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'd_1_0', 'd_2_0',
#        'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1', 'd_4_2', 'd_4_3',
#        'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1', 'd_6_2', 'd_6_3',
#        'scalar_coupling_constant', 'rc_A', 'rc_B', 'rc_C', 'mu', 'alpha',
#        'homo', 'lumo', 'gap', 'zpve', 'Cv', 'freqs_min', 'freqs_max',
#        'freqs_mean', 'mulliken_min', 'mulliken_max', 'mulliken_atom_0',
#        'mulliken_atom_1'],
#       dtype='object')

# %%
import xgboost as xgb

# %%
# xgb的参数
xgb_params = {'eta': 0.1,
              'max_depth': 11,
              'subsample': 0.9,
              'objective': 'reg:linear',
              'eval_metric': 'mae',
              'tree_method':'gpu_hist',
              'colsample_bytree':1,
              'alpha':0.2,
              'lambda':0.1,
             }

# %%
def train_and_predict_for_one_coupling_type(coupling_type, submission,oof_sub,n_atoms, n_folds=5,n_depth=9, n_splits=5, random_state=129):
    print(f'*** Training Model for {coupling_type} ***')
    # 训练集
    X_data, y_data = build_x_y_data(train_csv, coupling_type, n_atoms)
    # 测试集
    X_test, _ = build_x_y_data(test_csv, coupling_type, n_atoms)
    # 需要提交的数据
    y_pred = np.zeros(X_test.shape[0], dtype='float32')
    # oof本来使用了stacking的，后来没用上
    oof = np.zeros(X_data.shape[0],dtype='float32')
    # 交叉验证的分数
    cv_score = 0
    # K折交叉验证
    kfold = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)
    
    for fold, (train_index, val_index) in enumerate(kfold.split(X_data, y_data)):
        X_train, X_val = X_data[train_index], X_data[val_index]
        y_train, y_val = y_data[train_index], y_data[val_index]
        # 转化为DMatrix这样xgboost能用
        train_data=xgb.DMatrix(data=X_train,label=y_train)
        vaild_data=xgb.DMatrix(data=X_val,label=y_val)
        xgb_params['max_depth']=n_depth
        # 设置观测的指标
        watchlist = [(vaild_data, 'valid_data')]
        
        # iterations最多迭代次数，每个类别不一样
        if coupling_type in ['1JHN']:
            iterations=5000
        if coupling_type == '1JHC':
            iterations=6000
        else:
            iterations=4700
            
        # xgb开始训练
        model = xgb.train(dtrain=train_data, num_boost_round=iterations, evals=watchlist, early_stopping_rounds=250,params=xgb_params,verbose_eval=500)
        # xgb对验证集的预测结果
        y_val_pred=model.predict(xgb.DMatrix(X_val))
        # 得到验证集的分数
        val_score = np.log(mean_absolute_error(y_val, y_val_pred))
        oof[val_index]=y_val_pred
        print(f'{coupling_type} Fold {fold}, logMAE: {val_score}')
        cv_score += val_score / n_folds
        # xgb对测试集的预测结果
        y_pred += model.predict(xgb.DMatrix(X_test)) / n_folds

        
    submission.loc[test_csv['type'] == coupling_type, 'scalar_coupling_constant'] = y_pred
    oof_sub.loc[train_csv['type'] == coupling_type, 'scalar_coupling_constant'] = oof
    return cv_score

# %%
# 模型的n_atoms个数设置
model_params = {
    '1JHN': 10,
    '1JHC': 13,
    '2JHH': 10,
    '2JHN': 10,
    '2JHC': 10,
    '3JHH': 10,
    '3JHC': 10,
    '3JHN': 10
}
# 模型的深度设置
model_depth=\
{
    '1JHN': 11,
    '1JHC': 11,
    '2JHH': 11,
    '2JHN': 11,
    '2JHC': 11,
    '3JHH': 11,
    '3JHC': 11,
    '3JHN': 11
}
# 7折交叉验证
N_FOLDS = 7
# 
submission = submission_csv.copy()
oof_submission=train_csv[['type','scalar_coupling_constant']].copy()
oof_submission['scalar_coupling_constant']=0

# 对于每种类型都进行训练
cv_scores = {}
for coupling_type in model_params.keys():
    cv_score = train_and_predict_for_one_coupling_type(
        coupling_type, submission,oof_submission,n_atoms=model_params[coupling_type], n_folds=N_FOLDS,n_depth=model_depth[coupling_type],random_state=130)
    cv_scores[coupling_type] = cv_score
# Out:
# *** Training Model for 1JHN ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant', 'rc_A', 'rc_B', 'rc_C', 'mu', 'alpha',
#        'homo', 'lumo', 'gap', 'zpve', 'Cv', 'freqs_min', 'freqs_max',
#        'freqs_mean', 'mulliken_min', 'mulliken_max', 'mulliken_atom_0',
#        'mulliken_atom_1'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3', 'rc_A',
#        'rc_B', 'rc_C', 'mu', 'alpha', 'homo', 'lumo', 'gap', 'zpve', 'Cv',
#        'freqs_min', 'freqs_max', 'freqs_mean', 'mulliken_min', 'mulliken_max',
#        'mulliken_atom_0', 'mulliken_atom_1'],
#       dtype='object')
# [16:19:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:42.3943
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.311552
# [1000]	valid_data-mae:0.310172
# [1500]	valid_data-mae:0.309969
# [2000]	valid_data-mae:0.309899
# [2500]	valid_data-mae:0.309862
# [3000]	valid_data-mae:0.309836
# [3500]	valid_data-mae:0.30982
# [4000]	valid_data-mae:0.309806
# [4500]	valid_data-mae:0.309793
# [4699]	valid_data-mae:0.30979
# 1JHN Fold 0, logMAE: -1.171860933303833
# [16:20:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:42.1439
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.319189
# [1000]	valid_data-mae:0.317701
# [1500]	valid_data-mae:0.317501
# [2000]	valid_data-mae:0.317431
# [2500]	valid_data-mae:0.317395
# [3000]	valid_data-mae:0.317366
# [3500]	valid_data-mae:0.317345
# [4000]	valid_data-mae:0.317332
# [4500]	valid_data-mae:0.317325
# [4699]	valid_data-mae:0.317318
# 1JHN Fold 1, logMAE: -1.1478501558303833
# [16:22:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:42.4829
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.318961
# [1000]	valid_data-mae:0.317633
# [1500]	valid_data-mae:0.317433
# [2000]	valid_data-mae:0.317362
# [2500]	valid_data-mae:0.317321
# [3000]	valid_data-mae:0.317299
# [3500]	valid_data-mae:0.317281
# [4000]	valid_data-mae:0.317269
# [4500]	valid_data-mae:0.317262
# [4699]	valid_data-mae:0.31726
# 1JHN Fold 2, logMAE: -1.1480348110198975
# [16:23:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:42.3821
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.318279
# [1000]	valid_data-mae:0.316819
# [1500]	valid_data-mae:0.316643
# [2000]	valid_data-mae:0.316576
# [2500]	valid_data-mae:0.31654
# [3000]	valid_data-mae:0.316511
# [3500]	valid_data-mae:0.316493
# [4000]	valid_data-mae:0.316481
# [4500]	valid_data-mae:0.316469
# [4699]	valid_data-mae:0.316468
# 1JHN Fold 3, logMAE: -1.1505341529846191
# [16:24:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:42.1671
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.325279
# [1000]	valid_data-mae:0.323856
# [1500]	valid_data-mae:0.323652
# [2000]	valid_data-mae:0.323568
# [2500]	valid_data-mae:0.323533
# [3000]	valid_data-mae:0.323506
# [3500]	valid_data-mae:0.323489
# [4000]	valid_data-mae:0.323479
# [4500]	valid_data-mae:0.323469
# [4699]	valid_data-mae:0.323466
# 1JHN Fold 4, logMAE: -1.1286611557006836
# [16:25:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:42.1286
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.309237
# [1000]	valid_data-mae:0.307794
# [1500]	valid_data-mae:0.307601
# [2000]	valid_data-mae:0.30752
# [2500]	valid_data-mae:0.307485
# [3000]	valid_data-mae:0.307466
# [3500]	valid_data-mae:0.307447
# [4000]	valid_data-mae:0.307429
# [4500]	valid_data-mae:0.307421
# [4699]	valid_data-mae:0.307417
# 1JHN Fold 5, logMAE: -1.1795496940612793
# [16:26:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:42.2919
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.316526
# [1000]	valid_data-mae:0.314819
# [1500]	valid_data-mae:0.314584
# [2000]	valid_data-mae:0.3145
# [2500]	valid_data-mae:0.314458
# [3000]	valid_data-mae:0.314426
# [3500]	valid_data-mae:0.314409
# [4000]	valid_data-mae:0.314394
# [4500]	valid_data-mae:0.314381
# [4699]	valid_data-mae:0.314376
# 1JHN Fold 6, logMAE: -1.1571660041809082
# *** Training Model for 1JHC ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'atom_10', 'atom_11', 'atom_12', 'd_1_0', 'd_2_0', 'd_2_1',
#        'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0',
#        'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0',
#        'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0',
#        'd_9_1', 'd_9_2', 'd_9_3', 'd_10_0', 'd_10_1', 'd_10_2', 'd_10_3',
#        'd_11_0', 'd_11_1', 'd_11_2', 'd_11_3', 'd_12_0', 'd_12_1', 'd_12_2',
#        'd_12_3', 'scalar_coupling_constant', 'rc_A', 'rc_B', 'rc_C', 'mu',
#        'alpha', 'homo', 'lumo', 'gap', 'zpve', 'Cv', 'freqs_min', 'freqs_max',
#        'freqs_mean', 'mulliken_min', 'mulliken_max', 'mulliken_atom_0',
#        'mulliken_atom_1'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'atom_10', 'atom_11', 'atom_12', 'd_1_0', 'd_2_0', 'd_2_1',
#        'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0',
#        'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0',
#        'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0',
#        'd_9_1', 'd_9_2', 'd_9_3', 'd_10_0', 'd_10_1', 'd_10_2', 'd_10_3',
#        'd_11_0', 'd_11_1', 'd_11_2', 'd_11_3', 'd_12_0', 'd_12_1', 'd_12_2',
#        'd_12_3', 'rc_A', 'rc_B', 'rc_C', 'mu', 'alpha', 'homo', 'lumo', 'gap',
#        'zpve', 'Cv', 'freqs_min', 'freqs_max', 'freqs_mean', 'mulliken_min',
#        'mulliken_max', 'mulliken_atom_0', 'mulliken_atom_1'],
#       dtype='object')
# [16:30:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:85.032
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.657394
# [1000]	valid_data-mae:0.604983
# [1500]	valid_data-mae:0.588019
# [2000]	valid_data-mae:0.580101
# [2500]	valid_data-mae:0.576036
# [3000]	valid_data-mae:0.573746
# [3500]	valid_data-mae:0.572344
# [4000]	valid_data-mae:0.571483
# [4500]	valid_data-mae:0.570948
# [5000]	valid_data-mae:0.570597
# [5500]	valid_data-mae:0.57034
# [5999]	valid_data-mae:0.570169
# 1JHC Fold 0, logMAE: -0.5618219971656799
# [16:39:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:84.9561
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.659588
# [1000]	valid_data-mae:0.608163
# [1500]	valid_data-mae:0.590994
# [2000]	valid_data-mae:0.583059
# [2500]	valid_data-mae:0.579026
# [3000]	valid_data-mae:0.576717
# [3500]	valid_data-mae:0.575276
# [4000]	valid_data-mae:0.574411
# [4500]	valid_data-mae:0.573867
# [5000]	valid_data-mae:0.573509
# [5500]	valid_data-mae:0.573267
# [5999]	valid_data-mae:0.573092
# 1JHC Fold 1, logMAE: -0.5567084550857544
# [16:48:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:85.0386
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.662081
# [1000]	valid_data-mae:0.609844
# [1500]	valid_data-mae:0.591811
# [2000]	valid_data-mae:0.584091
# [2500]	valid_data-mae:0.579898
# [3000]	valid_data-mae:0.577552
# [3500]	valid_data-mae:0.576143
# [4000]	valid_data-mae:0.575275
# [4500]	valid_data-mae:0.574732
# [5000]	valid_data-mae:0.574375
# [5500]	valid_data-mae:0.574128
# [5999]	valid_data-mae:0.573963
# 1JHC Fold 2, logMAE: -0.55519038438797
# [16:57:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:85.0594
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.655106
# [1000]	valid_data-mae:0.602752
# [1500]	valid_data-mae:0.585469
# [2000]	valid_data-mae:0.577736
# [2500]	valid_data-mae:0.573686
# [3000]	valid_data-mae:0.571308
# [3500]	valid_data-mae:0.569948
# [4000]	valid_data-mae:0.569096
# [4500]	valid_data-mae:0.568548
# [5000]	valid_data-mae:0.568194
# [5500]	valid_data-mae:0.567953
# [5999]	valid_data-mae:0.567777
# 1JHC Fold 3, logMAE: -0.5660265684127808
# [17:06:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:85.0504
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.657885
# [1000]	valid_data-mae:0.606948
# [1500]	valid_data-mae:0.590115
# [2000]	valid_data-mae:0.582559
# [2500]	valid_data-mae:0.578463
# [3000]	valid_data-mae:0.576186
# [3500]	valid_data-mae:0.574791
# [4000]	valid_data-mae:0.573938
# [4500]	valid_data-mae:0.573402
# [5000]	valid_data-mae:0.573055
# [5500]	valid_data-mae:0.572816
# [5999]	valid_data-mae:0.57265
# 1JHC Fold 4, logMAE: -0.5574808716773987
# [17:15:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:85.0488
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.655353
# [1000]	valid_data-mae:0.603015
# [1500]	valid_data-mae:0.585204
# [2000]	valid_data-mae:0.577295
# [2500]	valid_data-mae:0.573215
# [3000]	valid_data-mae:0.570758
# [3500]	valid_data-mae:0.569352
# [4000]	valid_data-mae:0.568484
# [4500]	valid_data-mae:0.567926
# [5000]	valid_data-mae:0.567554
# [5500]	valid_data-mae:0.567313
# [5999]	valid_data-mae:0.567132
# 1JHC Fold 5, logMAE: -0.5671631097793579
# [17:23:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:85.021
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.658322
# [1000]	valid_data-mae:0.60659
# [1500]	valid_data-mae:0.589511
# [2000]	valid_data-mae:0.581493
# [2500]	valid_data-mae:0.577326
# [3000]	valid_data-mae:0.575006
# [3500]	valid_data-mae:0.573612
# [4000]	valid_data-mae:0.57273
# [4500]	valid_data-mae:0.572182
# [5000]	valid_data-mae:0.571817
# [5500]	valid_data-mae:0.571579
# [5999]	valid_data-mae:0.571408
# 1JHC Fold 6, logMAE: -0.5596514344215393
# *** Training Model for 2JHH ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant', 'rc_A', 'rc_B', 'rc_C', 'mu', 'alpha',
#        'homo', 'lumo', 'gap', 'zpve', 'Cv', 'freqs_min', 'freqs_max',
#        'freqs_mean', 'mulliken_min', 'mulliken_max', 'mulliken_atom_0',
#        'mulliken_atom_1'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3', 'rc_A',
#        'rc_B', 'rc_C', 'mu', 'alpha', 'homo', 'lumo', 'gap', 'zpve', 'Cv',
#        'freqs_min', 'freqs_max', 'freqs_mean', 'mulliken_min', 'mulliken_max',
#        'mulliken_atom_0', 'mulliken_atom_1'],
#       dtype='object')
# [17:34:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:9.89992
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.146523
# [1000]	valid_data-mae:0.140239
# [1500]	valid_data-mae:0.138419
# [2000]	valid_data-mae:0.137659
# [2500]	valid_data-mae:0.137309
# [3000]	valid_data-mae:0.137111
# [3500]	valid_data-mae:0.136995
# [4000]	valid_data-mae:0.136918
# [4500]	valid_data-mae:0.136861
# [4699]	valid_data-mae:0.136844
# 2JHH Fold 0, logMAE: -1.9889163970947266
# [17:38:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:9.88462
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.14705
# [1000]	valid_data-mae:0.140822
# [1500]	valid_data-mae:0.138985
# [2000]	valid_data-mae:0.138268
# [2500]	valid_data-mae:0.137926
# [3000]	valid_data-mae:0.137723
# [3500]	valid_data-mae:0.137611
# [4000]	valid_data-mae:0.137529
# [4500]	valid_data-mae:0.137481
# [4699]	valid_data-mae:0.137464
# 2JHH Fold 1, logMAE: -1.9843920469284058
# [17:43:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:9.8852
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.145429
# [1000]	valid_data-mae:0.139265
# [1500]	valid_data-mae:0.137492
# [2000]	valid_data-mae:0.136745
# [2500]	valid_data-mae:0.136395
# [3000]	valid_data-mae:0.136201
# [3500]	valid_data-mae:0.13608
# [4000]	valid_data-mae:0.136002
# [4500]	valid_data-mae:0.135951
# [4699]	valid_data-mae:0.135933
# 2JHH Fold 2, logMAE: -1.9955945014953613
# [17:47:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:9.90951
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.146533
# [1000]	valid_data-mae:0.14023
# [1500]	valid_data-mae:0.138405
# [2000]	valid_data-mae:0.137658
# [2500]	valid_data-mae:0.13732
# [3000]	valid_data-mae:0.137135
# [3500]	valid_data-mae:0.13702
# [4000]	valid_data-mae:0.136948
# [4500]	valid_data-mae:0.136896
# [4699]	valid_data-mae:0.136882
# 2JHH Fold 3, logMAE: -1.988638997077942
# [17:51:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:9.8853
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.146857
# [1000]	valid_data-mae:0.14055
# [1500]	valid_data-mae:0.138741
# [2000]	valid_data-mae:0.138066
# [2500]	valid_data-mae:0.137728
# [3000]	valid_data-mae:0.137547
# [3500]	valid_data-mae:0.137433
# [4000]	valid_data-mae:0.137361
# [4500]	valid_data-mae:0.137305
# [4699]	valid_data-mae:0.137288
# 2JHH Fold 4, logMAE: -1.9856735467910767
# [17:56:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:9.87189
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.14463
# [1000]	valid_data-mae:0.138706
# [1500]	valid_data-mae:0.136948
# [2000]	valid_data-mae:0.136239
# [2500]	valid_data-mae:0.135898
# [3000]	valid_data-mae:0.135709
# [3500]	valid_data-mae:0.135601
# [4000]	valid_data-mae:0.135525
# [4500]	valid_data-mae:0.135474
# [4699]	valid_data-mae:0.135454
# 2JHH Fold 5, logMAE: -1.9991222620010376
# [18:00:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:9.90673
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.146843
# [1000]	valid_data-mae:0.140739
# [1500]	valid_data-mae:0.138958
# [2000]	valid_data-mae:0.138251
# [2500]	valid_data-mae:0.1379
# [3000]	valid_data-mae:0.137705
# [3500]	valid_data-mae:0.137593
# [4000]	valid_data-mae:0.137517
# [4500]	valid_data-mae:0.137464
# [4699]	valid_data-mae:0.137445
# 2JHH Fold 6, logMAE: -1.9845309257507324
# *** Training Model for 2JHN ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant', 'rc_A', 'rc_B', 'rc_C', 'mu', 'alpha',
#        'homo', 'lumo', 'gap', 'zpve', 'Cv', 'freqs_min', 'freqs_max',
#        'freqs_mean', 'mulliken_min', 'mulliken_max', 'mulliken_atom_0',
#        'mulliken_atom_1'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3', 'rc_A',
#        'rc_B', 'rc_C', 'mu', 'alpha', 'homo', 'lumo', 'gap', 'zpve', 'Cv',
#        'freqs_min', 'freqs_max', 'freqs_mean', 'mulliken_min', 'mulliken_max',
#        'mulliken_atom_0', 'mulliken_atom_1'],
#       dtype='object')
# [18:05:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.83703
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.132358
# [1000]	valid_data-mae:0.129189
# [1500]	valid_data-mae:0.128513
# [2000]	valid_data-mae:0.128269
# [2500]	valid_data-mae:0.128154
# [3000]	valid_data-mae:0.128088
# [3500]	valid_data-mae:0.128041
# [4000]	valid_data-mae:0.128006
# [4500]	valid_data-mae:0.127982
# [4699]	valid_data-mae:0.127974
# 2JHN Fold 0, logMAE: -2.0559263229370117
# [18:07:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.8061
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.134518
# [1000]	valid_data-mae:0.130961
# [1500]	valid_data-mae:0.130192
# [2000]	valid_data-mae:0.129926
# [2500]	valid_data-mae:0.129807
# [3000]	valid_data-mae:0.129735
# [3500]	valid_data-mae:0.129692
# [4000]	valid_data-mae:0.129662
# [4500]	valid_data-mae:0.129635
# [4699]	valid_data-mae:0.129627
# 2JHN Fold 1, logMAE: -2.043092727661133
# [18:10:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.75113
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.136305
# [1000]	valid_data-mae:0.132648
# [1500]	valid_data-mae:0.131888
# [2000]	valid_data-mae:0.131618
# [2500]	valid_data-mae:0.131494
# [3000]	valid_data-mae:0.131422
# [3500]	valid_data-mae:0.131376
# [4000]	valid_data-mae:0.131343
# [4500]	valid_data-mae:0.131319
# [4699]	valid_data-mae:0.13131
# 2JHN Fold 2, logMAE: -2.0301918983459473
# [18:12:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.76671
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.133349
# [1000]	valid_data-mae:0.129731
# [1500]	valid_data-mae:0.128959
# [2000]	valid_data-mae:0.1287
# [2500]	valid_data-mae:0.128576
# [3000]	valid_data-mae:0.128506
# [3500]	valid_data-mae:0.128453
# [4000]	valid_data-mae:0.128422
# [4500]	valid_data-mae:0.128395
# [4699]	valid_data-mae:0.128387
# 2JHN Fold 3, logMAE: -2.0527055263519287
# [18:14:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.80055
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.136229
# [1000]	valid_data-mae:0.132824
# [1500]	valid_data-mae:0.132089
# [2000]	valid_data-mae:0.131837
# [2500]	valid_data-mae:0.131713
# [3000]	valid_data-mae:0.131642
# [3500]	valid_data-mae:0.131599
# [4000]	valid_data-mae:0.131566
# [4500]	valid_data-mae:0.131542
# [4699]	valid_data-mae:0.131532
# 2JHN Fold 4, logMAE: -2.028505563735962
# [18:16:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.79085
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.134934
# [1000]	valid_data-mae:0.131661
# [1500]	valid_data-mae:0.130925
# [2000]	valid_data-mae:0.130663
# [2500]	valid_data-mae:0.130539
# [3000]	valid_data-mae:0.130463
# [3500]	valid_data-mae:0.130416
# [4000]	valid_data-mae:0.130383
# [4500]	valid_data-mae:0.130358
# [4699]	valid_data-mae:0.130349
# 2JHN Fold 5, logMAE: -2.0375359058380127
# [18:18:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.80112
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.133421
# [1000]	valid_data-mae:0.129963
# [1500]	valid_data-mae:0.12918
# [2000]	valid_data-mae:0.128921
# [2500]	valid_data-mae:0.128805
# [3000]	valid_data-mae:0.128732
# [3500]	valid_data-mae:0.128686
# [4000]	valid_data-mae:0.128651
# [4500]	valid_data-mae:0.128629
# [4699]	valid_data-mae:0.128622
# 2JHN Fold 6, logMAE: -2.0508742332458496
# *** Training Model for 2JHC ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant', 'rc_A', 'rc_B', 'rc_C', 'mu', 'alpha',
#        'homo', 'lumo', 'gap', 'zpve', 'Cv', 'freqs_min', 'freqs_max',
#        'freqs_mean', 'mulliken_min', 'mulliken_max', 'mulliken_atom_0',
#        'mulliken_atom_1'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3', 'rc_A',
#        'rc_B', 'rc_C', 'mu', 'alpha', 'homo', 'lumo', 'gap', 'zpve', 'Cv',
#        'freqs_min', 'freqs_max', 'freqs_mean', 'mulliken_min', 'mulliken_max',
#        'mulliken_atom_0', 'mulliken_atom_1'],
#       dtype='object')
# [18:23:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.75793
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.289259
# [1000]	valid_data-mae:0.257374
# [1500]	valid_data-mae:0.245805
# [2000]	valid_data-mae:0.239689
# [2500]	valid_data-mae:0.236045
# [3000]	valid_data-mae:0.233736
# [3500]	valid_data-mae:0.232203
# [4000]	valid_data-mae:0.231087
# [4500]	valid_data-mae:0.230341
# [4699]	valid_data-mae:0.230095
# 2JHC Fold 0, logMAE: -1.4692631959915161
# [18:30:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.74335
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.287372
# [1000]	valid_data-mae:0.255448
# [1500]	valid_data-mae:0.243111
# [2000]	valid_data-mae:0.236975
# [2500]	valid_data-mae:0.233318
# [3000]	valid_data-mae:0.231012
# [3500]	valid_data-mae:0.229451
# [4000]	valid_data-mae:0.228359
# [4500]	valid_data-mae:0.227574
# [4699]	valid_data-mae:0.227332
# 2JHC Fold 1, logMAE: -1.481345772743225
# [18:38:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.74168
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.288703
# [1000]	valid_data-mae:0.257392
# [1500]	valid_data-mae:0.245512
# [2000]	valid_data-mae:0.239308
# [2500]	valid_data-mae:0.235607
# [3000]	valid_data-mae:0.233295
# [3500]	valid_data-mae:0.231724
# [4000]	valid_data-mae:0.230633
# [4500]	valid_data-mae:0.229851
# [4699]	valid_data-mae:0.229602
# 2JHC Fold 2, logMAE: -1.471406102180481
# [18:46:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.73454
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.289834
# [1000]	valid_data-mae:0.257612
# [1500]	valid_data-mae:0.245448
# [2000]	valid_data-mae:0.239253
# [2500]	valid_data-mae:0.235461
# [3000]	valid_data-mae:0.233066
# [3500]	valid_data-mae:0.231474
# [4000]	valid_data-mae:0.230367
# [4500]	valid_data-mae:0.22956
# [4699]	valid_data-mae:0.229301
# 2JHC Fold 3, logMAE: -1.4727193117141724
# [18:54:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.75291
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.288656
# [1000]	valid_data-mae:0.257533
# [1500]	valid_data-mae:0.245348
# [2000]	valid_data-mae:0.239153
# [2500]	valid_data-mae:0.235405
# [3000]	valid_data-mae:0.23303
# [3500]	valid_data-mae:0.231449
# [4000]	valid_data-mae:0.230387
# [4500]	valid_data-mae:0.229588
# [4699]	valid_data-mae:0.229338
# 2JHC Fold 4, logMAE: -1.472556710243225
# [19:02:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.74875
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.286688
# [1000]	valid_data-mae:0.25596
# [1500]	valid_data-mae:0.243749
# [2000]	valid_data-mae:0.237586
# [2500]	valid_data-mae:0.23395
# [3000]	valid_data-mae:0.231626
# [3500]	valid_data-mae:0.230084
# [4000]	valid_data-mae:0.229029
# [4500]	valid_data-mae:0.228266
# [4699]	valid_data-mae:0.228019
# 2JHC Fold 5, logMAE: -1.4783241748809814
# [19:09:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:2.74848
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.288474
# [1000]	valid_data-mae:0.257129
# [1500]	valid_data-mae:0.24474
# [2000]	valid_data-mae:0.238783
# [2500]	valid_data-mae:0.235124
# [3000]	valid_data-mae:0.232853
# [3500]	valid_data-mae:0.231257
# [4000]	valid_data-mae:0.23014
# [4500]	valid_data-mae:0.229363
# [4699]	valid_data-mae:0.229113
# 2JHC Fold 6, logMAE: -1.4735405445098877
# *** Training Model for 3JHH ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant', 'rc_A', 'rc_B', 'rc_C', 'mu', 'alpha',
#        'homo', 'lumo', 'gap', 'zpve', 'Cv', 'freqs_min', 'freqs_max',
#        'freqs_mean', 'mulliken_min', 'mulliken_max', 'mulliken_atom_0',
#        'mulliken_atom_1'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3', 'rc_A',
#        'rc_B', 'rc_C', 'mu', 'alpha', 'homo', 'lumo', 'gap', 'zpve', 'Cv',
#        'freqs_min', 'freqs_max', 'freqs_mean', 'mulliken_min', 'mulliken_max',
#        'mulliken_atom_0', 'mulliken_atom_1'],
#       dtype='object')
# [19:18:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.9941
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.172394
# [1000]	valid_data-mae:0.158726
# [1500]	valid_data-mae:0.154032
# [2000]	valid_data-mae:0.151973
# [2500]	valid_data-mae:0.150924
# [3000]	valid_data-mae:0.150313
# [3500]	valid_data-mae:0.149941
# [4000]	valid_data-mae:0.149707
# [4500]	valid_data-mae:0.149559
# [4699]	valid_data-mae:0.14951
# 3JHH Fold 0, logMAE: -1.9003890752792358
# [19:24:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.96842
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.172435
# [1000]	valid_data-mae:0.158634
# [1500]	valid_data-mae:0.153941
# [2000]	valid_data-mae:0.151836
# [2500]	valid_data-mae:0.150726
# [3000]	valid_data-mae:0.15012
# [3500]	valid_data-mae:0.149758
# [4000]	valid_data-mae:0.149527
# [4500]	valid_data-mae:0.149371
# [4699]	valid_data-mae:0.149319
# 3JHH Fold 1, logMAE: -1.901669979095459
# [19:30:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.96258
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.172048
# [1000]	valid_data-mae:0.158531
# [1500]	valid_data-mae:0.15401
# [2000]	valid_data-mae:0.15191
# [2500]	valid_data-mae:0.150791
# [3000]	valid_data-mae:0.150187
# [3500]	valid_data-mae:0.14982
# [4000]	valid_data-mae:0.149599
# [4500]	valid_data-mae:0.149447
# [4699]	valid_data-mae:0.149395
# 3JHH Fold 2, logMAE: -1.9011584520339966
# [19:35:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.99463
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.172045
# [1000]	valid_data-mae:0.158602
# [1500]	valid_data-mae:0.154032
# [2000]	valid_data-mae:0.151905
# [2500]	valid_data-mae:0.150881
# [3000]	valid_data-mae:0.150288
# [3500]	valid_data-mae:0.149943
# [4000]	valid_data-mae:0.149716
# [4500]	valid_data-mae:0.149566
# [4699]	valid_data-mae:0.14952
# 3JHH Fold 3, logMAE: -1.9003276824951172
# [19:41:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.97265
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.171677
# [1000]	valid_data-mae:0.158231
# [1500]	valid_data-mae:0.153696
# [2000]	valid_data-mae:0.151593
# [2500]	valid_data-mae:0.150553
# [3000]	valid_data-mae:0.149965
# [3500]	valid_data-mae:0.149606
# [4000]	valid_data-mae:0.149366
# [4500]	valid_data-mae:0.149205
# [4699]	valid_data-mae:0.14916
# 3JHH Fold 4, logMAE: -1.9027336835861206
# [19:46:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.98182
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.172284
# [1000]	valid_data-mae:0.158813
# [1500]	valid_data-mae:0.154243
# [2000]	valid_data-mae:0.152179
# [2500]	valid_data-mae:0.151114
# [3000]	valid_data-mae:0.150522
# [3500]	valid_data-mae:0.150161
# [4000]	valid_data-mae:0.149937
# [4500]	valid_data-mae:0.149793
# [4699]	valid_data-mae:0.149746
# 3JHH Fold 5, logMAE: -1.8988131284713745
# [19:52:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.98443
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.170369
# [1000]	valid_data-mae:0.157141
# [1500]	valid_data-mae:0.152433
# [2000]	valid_data-mae:0.150388
# [2500]	valid_data-mae:0.149306
# [3000]	valid_data-mae:0.148716
# [3500]	valid_data-mae:0.148348
# [4000]	valid_data-mae:0.148128
# [4500]	valid_data-mae:0.147971
# [4699]	valid_data-mae:0.147919
# 3JHH Fold 6, logMAE: -1.9110914468765259
# *** Training Model for 3JHC ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant', 'rc_A', 'rc_B', 'rc_C', 'mu', 'alpha',
#        'homo', 'lumo', 'gap', 'zpve', 'Cv', 'freqs_min', 'freqs_max',
#        'freqs_mean', 'mulliken_min', 'mulliken_max', 'mulliken_atom_0',
#        'mulliken_atom_1'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3', 'rc_A',
#        'rc_B', 'rc_C', 'mu', 'alpha', 'homo', 'lumo', 'gap', 'zpve', 'Cv',
#        'freqs_min', 'freqs_max', 'freqs_mean', 'mulliken_min', 'mulliken_max',
#        'mulliken_atom_0', 'mulliken_atom_1'],
#       dtype='object')
# [20:00:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.00904
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.312561
# [1000]	valid_data-mae:0.278645
# [1500]	valid_data-mae:0.264562
# [2000]	valid_data-mae:0.256933
# [2500]	valid_data-mae:0.252271
# [3000]	valid_data-mae:0.249147
# [3500]	valid_data-mae:0.246926
# [4000]	valid_data-mae:0.245318
# [4500]	valid_data-mae:0.244126
# [4699]	valid_data-mae:0.243749
# 3JHC Fold 0, logMAE: -1.4116177558898926
# [20:09:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.01995
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.312752
# [1000]	valid_data-mae:0.277768
# [1500]	valid_data-mae:0.263714
# [2000]	valid_data-mae:0.256067
# [2500]	valid_data-mae:0.251398
# [3000]	valid_data-mae:0.248328
# [3500]	valid_data-mae:0.246193
# [4000]	valid_data-mae:0.244608
# [4500]	valid_data-mae:0.243478
# [4699]	valid_data-mae:0.243111
# 3JHC Fold 1, logMAE: -1.414237380027771
# [20:18:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.00125
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.31262
# [1000]	valid_data-mae:0.278511
# [1500]	valid_data-mae:0.264678
# [2000]	valid_data-mae:0.257073
# [2500]	valid_data-mae:0.252297
# [3000]	valid_data-mae:0.249161
# [3500]	valid_data-mae:0.246939
# [4000]	valid_data-mae:0.245323
# [4500]	valid_data-mae:0.24412
# [4699]	valid_data-mae:0.243739
# 3JHC Fold 2, logMAE: -1.411658525466919
# [20:27:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.00897
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.311801
# [1000]	valid_data-mae:0.277622
# [1500]	valid_data-mae:0.263909
# [2000]	valid_data-mae:0.256089
# [2500]	valid_data-mae:0.251419
# [3000]	valid_data-mae:0.248387
# [3500]	valid_data-mae:0.246193
# [4000]	valid_data-mae:0.24461
# [4500]	valid_data-mae:0.243431
# [4699]	valid_data-mae:0.243037
# 3JHC Fold 3, logMAE: -1.4145420789718628
# [20:35:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.00536
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.309794
# [1000]	valid_data-mae:0.275817
# [1500]	valid_data-mae:0.26204
# [2000]	valid_data-mae:0.254557
# [2500]	valid_data-mae:0.249909
# [3000]	valid_data-mae:0.246809
# [3500]	valid_data-mae:0.244625
# [4000]	valid_data-mae:0.243038
# [4500]	valid_data-mae:0.241909
# [4699]	valid_data-mae:0.241537
# 3JHC Fold 4, logMAE: -1.4207309484481812
# [20:44:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.00459
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.310206
# [1000]	valid_data-mae:0.275794
# [1500]	valid_data-mae:0.262348
# [2000]	valid_data-mae:0.254917
# [2500]	valid_data-mae:0.250282
# [3000]	valid_data-mae:0.247209
# [3500]	valid_data-mae:0.245019
# [4000]	valid_data-mae:0.243499
# [4500]	valid_data-mae:0.242348
# [4699]	valid_data-mae:0.241962
# 3JHC Fold 5, logMAE: -1.4189726114273071
# [20:53:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:3.00231
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.310067
# [1000]	valid_data-mae:0.275792
# [1500]	valid_data-mae:0.262102
# [2000]	valid_data-mae:0.254675
# [2500]	valid_data-mae:0.249893
# [3000]	valid_data-mae:0.246849
# [3500]	valid_data-mae:0.244678
# [4000]	valid_data-mae:0.243143
# [4500]	valid_data-mae:0.241977
# [4699]	valid_data-mae:0.241607
# 3JHC Fold 6, logMAE: -1.4204421043395996
# *** Training Model for 3JHN ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant', 'rc_A', 'rc_B', 'rc_C', 'mu', 'alpha',
#        'homo', 'lumo', 'gap', 'zpve', 'Cv', 'freqs_min', 'freqs_max',
#        'freqs_mean', 'mulliken_min', 'mulliken_max', 'mulliken_atom_0',
#        'mulliken_atom_1'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3', 'rc_A',
#        'rc_B', 'rc_C', 'mu', 'alpha', 'homo', 'lumo', 'gap', 'zpve', 'Cv',
#        'freqs_min', 'freqs_max', 'freqs_mean', 'mulliken_min', 'mulliken_max',
#        'mulliken_atom_0', 'mulliken_atom_1'],
#       dtype='object')
# [21:03:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:0.849956
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.108183
# [1000]	valid_data-mae:0.104199
# [1500]	valid_data-mae:0.103245
# [2000]	valid_data-mae:0.102887
# [2500]	valid_data-mae:0.102724
# [3000]	valid_data-mae:0.10263
# [3500]	valid_data-mae:0.102567
# [4000]	valid_data-mae:0.102527
# [4500]	valid_data-mae:0.102499
# [4699]	valid_data-mae:0.102489
# 3JHN Fold 0, logMAE: -2.278000593185425
# [21:06:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:0.854187
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.110831
# [1000]	valid_data-mae:0.106802
# [1500]	valid_data-mae:0.105777
# [2000]	valid_data-mae:0.105417
# [2500]	valid_data-mae:0.105237
# [3000]	valid_data-mae:0.105136
# [3500]	valid_data-mae:0.105072
# [4000]	valid_data-mae:0.10503
# [4500]	valid_data-mae:0.105002
# [4699]	valid_data-mae:0.104991
# 3JHN Fold 1, logMAE: -2.2538833618164062
# [21:08:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:0.848697
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.108592
# [1000]	valid_data-mae:0.104624
# [1500]	valid_data-mae:0.103684
# [2000]	valid_data-mae:0.103345
# [2500]	valid_data-mae:0.103189
# [3000]	valid_data-mae:0.103098
# [3500]	valid_data-mae:0.103039
# [4000]	valid_data-mae:0.102999
# [4500]	valid_data-mae:0.10297
# [4699]	valid_data-mae:0.10296
# 3JHN Fold 2, logMAE: -2.273411750793457
# [21:11:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:0.8615
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.110655
# [1000]	valid_data-mae:0.106648
# [1500]	valid_data-mae:0.105708
# [2000]	valid_data-mae:0.105349
# [2500]	valid_data-mae:0.10518
# [3000]	valid_data-mae:0.10508
# [3500]	valid_data-mae:0.105021
# [4000]	valid_data-mae:0.104978
# [4500]	valid_data-mae:0.104946
# [4699]	valid_data-mae:0.104936
# 3JHN Fold 3, logMAE: -2.2544002532958984
# [21:14:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:0.849181
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.108648
# [1000]	valid_data-mae:0.104588
# [1500]	valid_data-mae:0.103625
# [2000]	valid_data-mae:0.103273
# [2500]	valid_data-mae:0.1031
# [3000]	valid_data-mae:0.103
# [3500]	valid_data-mae:0.102936
# [4000]	valid_data-mae:0.102894
# [4500]	valid_data-mae:0.102861
# [4699]	valid_data-mae:0.102853
# 3JHN Fold 4, logMAE: -2.274454116821289
# [21:16:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:0.8447
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.109832
# [1000]	valid_data-mae:0.105805
# [1500]	valid_data-mae:0.104863
# [2000]	valid_data-mae:0.104508
# [2500]	valid_data-mae:0.104337
# [3000]	valid_data-mae:0.104238
# [3500]	valid_data-mae:0.104177
# [4000]	valid_data-mae:0.104135
# [4500]	valid_data-mae:0.104107
# [4699]	valid_data-mae:0.104097
# 3JHN Fold 5, logMAE: -2.262434959411621
# [21:19:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	valid_data-mae:0.849596
# Will train until valid_data-mae hasn't improved in 250 rounds.
# [500]	valid_data-mae:0.10887
# [1000]	valid_data-mae:0.104917
# [1500]	valid_data-mae:0.103993
# [2000]	valid_data-mae:0.10364
# [2500]	valid_data-mae:0.103465
# [3000]	valid_data-mae:0.10337
# [3500]	valid_data-mae:0.103306
# [4000]	valid_data-mae:0.103265
# [4500]	valid_data-mae:0.103236
# [4699]	valid_data-mae:0.103227
# 3JHN Fold 6, logMAE: -2.270824670791626

# %%
oof_submission.head()
oof_submission.to_csv('xgb_oof.csv',index=False)

# %%
train_csv.head()
# Out:
#     molecule_index  atom_index_0  atom_index_1  type  scalar_coupling_constant
# id
# 0   1               1             0             1JHC  84.807602
# 1   1               1             2             2JHH -11.257000
# 2   1               1             3             2JHH -11.254800
# 3   1               1             4             2JHH -11.254300
# 4   1               2             0             1JHC  84.807404

# %%
submission_csv.head()
# Out:
#          scalar_coupling_constant
# id
# 4658147  0
# 4658148  0
# 4658149  0
# 4658150  0
# 4658151  0

# %%
pd.DataFrame({'type': list(cv_scores.keys()), 'cv_score': list(cv_scores.values())})
# Out:
#    type  cv_score
# 0  1JHN -1.154808
# 1  1JHC -0.560578
# 2  2JHH -1.989553
# 3  2JHN -2.042690
# 4  2JHC -1.474165
# 5  3JHH -1.902312
# 6  3JHC -1.416029
# 7  3JHN -2.266773

# %%
# 打印交叉验证的分数
np.mean(list(cv_scores.values()))
# Out:
# -1.6008634098938535

# %%
submission.head(10)
# Out:
#          scalar_coupling_constant
# id
# 4658147  22.284721
# 4658148  122.587364
# 4658149  5.333972
# 4658150  122.587364
# 4658151  22.284721
# 4658152  91.971840
# 4658153  2.361273
# 4658154 -7.788785
# 4658155 -9.673582
# 4658156  91.971405

# %%
# 提交最终结果
submission.to_csv(f'{SUBMISSIONS_PATH}/submission.csv')

# %% [markdown]
# ## Room for improvement
